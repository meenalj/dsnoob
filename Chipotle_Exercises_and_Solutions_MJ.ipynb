# %% [markdown]
# <a href="https://colab.research.google.com/github/meenalj/dsnoob/blob/master/Chipotle_Exercises_and_Solutions_MJ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %%
chipo.head(5)
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
#
# [5 rows x 5 columns]

# %%
chipo.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
## for number comparisons, the dtype should be float but the column has $ in it
##Cleansing the data
prices = [float(value[1 : -1]) for value in chipo.item_price]   #Value[1:-1] is a substring reading from char 1 which is 2nd character. [1:-2] removes the last decimal
chipo.item_price=prices
chipo.head(10)
# Out:
#    order_id  ...  item_price
# 0         1  ...        2.39
# 1         1  ...        3.39
# 2         1  ...        3.39
# 3         1  ...        2.39
# 4         2  ...       16.98
# 5         3  ...       10.98
# 6         3  ...        1.69
# 7         4  ...       11.75
# 8         4  ...        9.25
# 9         5  ...        9.25
#
# [10 rows x 5 columns]

# %%
## Essentially looking for what product is greater than $10 - Looking at the data shows that there are a lot of dupes in the sense you only want item costing greter than 10 $ 
##Example is row above with index=5
chipo_dropdupes= chipo.drop_duplicates(['item_name','quantity'])

# %%
## Now, from the data, it looks like the item_price is actually order price and not price per item.This would mean, to find a product costing greater than $10, you need quantity =1
chipo_one_product = chipo_dropdupes[chipo_dropdupes.quantity == 1]
chipo_one_product.head(10)
# Out:
#     order_id  ...  item_price
# 0          1  ...        2.39
# 1          1  ...        3.39
# 2          1  ...        3.39
# 3          1  ...        2.39
# 5          3  ...       10.98
# 6          3  ...        1.69
# 7          4  ...       11.75
# 8          4  ...        9.25
# 10         5  ...        4.45
# 11         6  ...        8.75
#
# [10 rows x 5 columns]

# %%
#Based on the final one product only dataset, you can now choose the product with cost greater than 10$- Example index 7
chipo_one_product[chipo_one_product.item_price>10]
chipo_one_product # this gives dupes too
print chipo_one_product[chipo_one_product.item_price>10].item_name.unique() # THis gives names
chipo_one_product[chipo_one_product.item_price>10].item_name.nunique() #This gives count
# Out:
# ['Chicken Bowl' 'Steak Burrito' 'Barbacoa Bowl' 'Veggie Burrito'
#  'Veggie Bowl' 'Barbacoa Crispy Tacos' 'Veggie Salad Bowl' 'Chicken Salad'
#  'Steak Salad Bowl' 'Veggie Soft Tacos' 'Carnitas Salad Bowl'
#  'Barbacoa Salad Bowl']
# 12

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
# In this case again, you need to drop dupes, filter for quantity 1
print chipo.count()
chipo_dropdupes_2= chipo.drop_duplicates(['item_name'])
print chipo_dropdupes_2.count()
chipo_dropdupes_2.head(10)
chipo_subset=chipo_dropdupes_2[['item_name','item_price']]
print chipo_subset.sort_values(by='item_name')
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64
# order_id              50
# quantity              50
# item_name             50
# choice_description    38
# item_price            50
# dtype: int64
#                                   item_name  item_price
# 298                       6 Pack Soft Drink        6.49
# 39                            Barbacoa Bowl       11.75
# 21                         Barbacoa Burrito        8.99
# 168                   Barbacoa Crispy Tacos       11.75
# 1229                    Barbacoa Salad Bowl       11.89
# 56                      Barbacoa Soft Tacos        9.25
# 34                            Bottled Water        1.09
# 445                                    Bowl       22.20
# 510                                 Burrito        7.40
# 18                              Canned Soda        2.18
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.item_name.sort_values #Method1 - sorts data for that column

chipo.sort_values(by='item_name') #Method2 - sorts table by that column
# Out:
#       order_id  ...  item_price
# 3389      1360  ...       12.98
# 341        148  ...        6.49
# 1849       749  ...        6.49
# 1860       754  ...        6.49
# 2713      1076  ...        6.49
# 3422      1373  ...        6.49
# 553        230  ...        6.49
# 1916       774  ...        6.49
# 1922       776  ...        6.49
# 1937       784  ...        6.49
# 3836      1537  ...        6.49
# 298        129  ...        6.49
# 1976       798  ...        6.49
# 1167       481  ...        6.49
# 3875      1554  ...        6.49
# 1124       465  ...        6.49
# 3886      1558  ...        6.49
# 2108       849  ...        6.49
# 3010      1196  ...        6.49
# 4535      1803  ...        6.49
# 4169      1664  ...        6.49
# 4174      1666  ...        6.49
# 4527      1800  ...        6.49
# 4522      1798  ...        6.49
# 3806      1525  ...        6.49
# 2389       949  ...        6.49
# 3132      1248  ...        6.49
# 3141      1253  ...        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by='item_price',ascending=False).head(1)
# Out:
#       order_id  quantity  ... choice_description item_price
# 3598      1443        15  ...                NaN      44.25
#
# [1 rows x 5 columns]

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
chipo_salad = chipo[chipo.item_name == "Veggie Salad Bowl"]

len(chipo_salad)
chipo_salad.count()
# Out:
# order_id              18
# quantity              18
# item_name             18
# choice_description    18
# item_price            18
# dtype: int64

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
chipo_drink = chipo[(chipo.item_name == "Canned Soda") & (chipo.quantity > 1)]
len(chipo_drink)
# Out:
# 20
